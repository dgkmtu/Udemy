# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.utils import np_utils
import keras
import numpy as np

# %%
classes = ['stripey', 'sea_goldie', 'neon_damselfish']
num_classes = len(classes)
image_size = 50

# %%
X_train, X_test, Y_train, Y_test = np.load('./fish.npy', allow_pickle=True)
X_train = X_train.astype('float') / 256
X_test  = X_test.astype('float') / 256
Y_train = np_utils.to_categorical(Y_train, num_classes)
Y_test  = np_utils.to_categorical(Y_test, num_classes)

# %%
def model_train(X, Y):
    model = Sequential()
    model.add(Conv2D(32, (3, 3), padding='same', input_shape=X.shape[1:]))
    model.add(Activation('relu'))
    model.add(Conv2D(32, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(3)) # number of images
    model.add(Activation('softmax'))

    #opt = keras.optimizers.Adam()
    opt = keras.optimizers.rmsprop(lr=0.0001, decay=1e-6)
    model.compile(loss='categorical_crossentropy',
                    optimizer=opt, metrics=['accuracy'])

    model.fit(X, Y, batch_size=32, epochs=100)

    # save model
    model.save('./fish_cnn.h5')

    return model

# %%
def model_eval(model, X, Y):
    scores = model.evaluate(X, Y, verbose=1)
    print('Test loss: ', scores[0])
    print('Test Accuracy: ', scores[1])

# %%
model = model_train(X_train, Y_train)
model_eval(model, X_test, Y_test)
# Out:
# Epoch 1/100
# 450/450 [==============================] - 2s 4ms/step - loss: 1.0993 - accuracy: 0.3600
# Epoch 2/100
# 450/450 [==============================] - 2s 4ms/step - loss: 1.0083 - accuracy: 0.5511
# Epoch 3/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.8464 - accuracy: 0.6622
# Epoch 4/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.7106 - accuracy: 0.7311
# Epoch 5/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.5939 - accuracy: 0.7533
# Epoch 6/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.5213 - accuracy: 0.7778
# Epoch 7/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.4553 - accuracy: 0.8089
# Epoch 8/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.4132 - accuracy: 0.8400
# Epoch 9/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.3868 - accuracy: 0.8622
# Epoch 10/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.3400 - accuracy: 0.8667
# Epoch 11/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.3259 - accuracy: 0.8933
# Epoch 12/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.2759 - accuracy: 0.9200
# Epoch 13/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.2845 - accuracy: 0.8978
# Epoch 14/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.2443 - accuracy: 0.9222
# Epoch 15/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.2382 - accuracy: 0.8956
# Epoch 16/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.2141 - accuracy: 0.9200
# Epoch 17/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.2128 - accuracy: 0.9289
# Epoch 18/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.1946 - accuracy: 0.9356
# Epoch 19/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.1946 - accuracy: 0.9311
# Epoch 20/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.1786 - accuracy: 0.9311
# Epoch 21/100
# 450/450 [==============================] - 2s 5ms/step - loss: 0.1575 - accuracy: 0.9489
# Epoch 22/100
# 450/450 [==============================] - 2s 5ms/step - loss: 0.1530 - accuracy: 0.9556
# Epoch 23/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.1553 - accuracy: 0.9578
# Epoch 24/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.1394 - accuracy: 0.9600
# Epoch 25/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.1351 - accuracy: 0.9578
# Epoch 26/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.1241 - accuracy: 0.9600
# Epoch 27/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.1311 - accuracy: 0.9489
# Epoch 28/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.1077 - accuracy: 0.9644
# Epoch 29/100
# 450/450 [==============================] - 2s 5ms/step - loss: 0.1138 - accuracy: 0.9556
# Epoch 30/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.1050 - accuracy: 0.9622
# Epoch 31/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0958 - accuracy: 0.9689
# Epoch 32/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0837 - accuracy: 0.9667
# Epoch 33/100
# 450/450 [==============================] - 2s 5ms/step - loss: 0.0993 - accuracy: 0.9689
# Epoch 34/100
# 450/450 [==============================] - 2s 5ms/step - loss: 0.0911 - accuracy: 0.9711
# Epoch 35/100
# 450/450 [==============================] - 2s 5ms/step - loss: 0.0989 - accuracy: 0.9711
# Epoch 36/100
# 450/450 [==============================] - 2s 5ms/step - loss: 0.0771 - accuracy: 0.9756
# Epoch 37/100
# 450/450 [==============================] - 2s 5ms/step - loss: 0.0797 - accuracy: 0.9733
# Epoch 38/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0882 - accuracy: 0.9756
# Epoch 39/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0811 - accuracy: 0.9756
# Epoch 40/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0768 - accuracy: 0.9822
# Epoch 41/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0580 - accuracy: 0.9822
# Epoch 42/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0527 - accuracy: 0.9800
# Epoch 43/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0527 - accuracy: 0.9867
# Epoch 44/100
# 450/450 [==============================] - 2s 5ms/step - loss: 0.0701 - accuracy: 0.9711
# Epoch 45/100
# 450/450 [==============================] - 2s 5ms/step - loss: 0.0447 - accuracy: 0.9889
# Epoch 46/100
# 450/450 [==============================] - 2s 5ms/step - loss: 0.0642 - accuracy: 0.9778
# Epoch 47/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0454 - accuracy: 0.9844
# Epoch 48/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0358 - accuracy: 0.9889
# Epoch 49/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0427 - accuracy: 0.9889
# Epoch 50/100
# 450/450 [==============================] - 2s 5ms/step - loss: 0.0521 - accuracy: 0.9889
# Epoch 51/100
# 450/450 [==============================] - 2s 5ms/step - loss: 0.0356 - accuracy: 0.9911
# Epoch 52/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0426 - accuracy: 0.9867
# Epoch 53/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0393 - accuracy: 0.9911
# Epoch 54/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0374 - accuracy: 0.9867
# Epoch 55/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0313 - accuracy: 0.9911
# Epoch 56/100
# 450/450 [==============================] - 2s 5ms/step - loss: 0.0532 - accuracy: 0.9800
# Epoch 57/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0512 - accuracy: 0.9867
# Epoch 58/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0191 - accuracy: 0.9978
# Epoch 59/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0376 - accuracy: 0.9889
# Epoch 60/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0502 - accuracy: 0.9822
# Epoch 61/100
# 450/450 [==============================] - 2s 5ms/step - loss: 0.0388 - accuracy: 0.9844
# Epoch 62/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0298 - accuracy: 0.9889
# Epoch 63/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0262 - accuracy: 0.9956
# Epoch 64/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0267 - accuracy: 0.9911
# Epoch 65/100
# 450/450 [==============================] - 2s 5ms/step - loss: 0.0186 - accuracy: 0.9956
# Epoch 66/100
# 450/450 [==============================] - 2s 5ms/step - loss: 0.0174 - accuracy: 0.9978
# Epoch 67/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0112 - accuracy: 0.9978
# Epoch 68/100
# 450/450 [==============================] - 2s 5ms/step - loss: 0.0166 - accuracy: 0.9956
# Epoch 69/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0130 - accuracy: 0.9978
# Epoch 70/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0115 - accuracy: 0.9978
# Epoch 71/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0328 - accuracy: 0.9867
# Epoch 72/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0269 - accuracy: 0.9889
# Epoch 73/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 74/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0176 - accuracy: 0.9933
# Epoch 75/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0139 - accuracy: 0.9956
# Epoch 76/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0198 - accuracy: 0.9933
# Epoch 77/100
# 450/450 [==============================] - 2s 5ms/step - loss: 0.0120 - accuracy: 0.9933
# Epoch 78/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0151 - accuracy: 0.9933
# Epoch 79/100
# 450/450 [==============================] - 2s 5ms/step - loss: 0.0147 - accuracy: 0.9933
# Epoch 80/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 81/100
# 450/450 [==============================] - 2s 5ms/step - loss: 0.0072 - accuracy: 0.9978
# Epoch 82/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0122 - accuracy: 0.9978
# Epoch 83/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0112 - accuracy: 0.9956
# Epoch 84/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 85/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0110 - accuracy: 0.9978
# Epoch 86/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0161 - accuracy: 0.9911
# Epoch 87/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0116 - accuracy: 0.9933
# Epoch 88/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 89/100
# 450/450 [==============================] - 2s 5ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 90/100
# 450/450 [==============================] - 2s 5ms/step - loss: 0.0281 - accuracy: 0.9889
# Epoch 91/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 92/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 93/100
# 450/450 [==============================] - 2s 5ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 94/100
# 450/450 [==============================] - 2s 5ms/step - loss: 0.0071 - accuracy: 0.9978
# Epoch 95/100
# 450/450 [==============================] - 2s 5ms/step - loss: 0.0158 - accuracy: 0.9933
# Epoch 96/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0107 - accuracy: 0.9956
# Epoch 97/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 98/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0080 - accuracy: 0.9956
# Epoch 99/100
# 450/450 [==============================] - 2s 5ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 100/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.0099 - accuracy: 0.9956
# 150/150 [==============================] - 0s 1ms/step
# Test loss:  0.3664640841881434
# Test Accuracy:  0.9466666579246521
